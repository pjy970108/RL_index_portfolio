# %%
import pandas as pd
import numpy as np
import robustsharpe as rs

# %%
test_return = pd.read_csv("./benchmark/bench_mark_return.csv", header=0, index_col=0)

# %%
test_return.columns
# Out:
# Index(['risk_parity', 'min_var', 'max_sharpe', 'paa', 'equal_strategy',
#        'equal_asset_weight'],
#       dtype='object')

# %%
benchmark_returns = np.array(test_return["equal_asset_weight"])

col_list = ['risk_parity', 'min_var', 'max_sharpe', 'paa', 'equal_strategy']
for col in col_list:
    my_strategy_returns = np.array(test_return[col])
    
    returns = np.stack([my_strategy_returns, benchmark_returns], axis=1)  # shape: (T, 2)
    SRs, diff, ci, pval, se, d = rs.bootstrap_inference(
        returns=returns,
        block_size=4,     # 논문 추천값 (T=120 기준)
        alpha=0.05,
        M=1000
    )
    print(f"Results for {col}:")
    print("Sharpe ratio (벤치마크, 내):", SRs)
    print("Sharpe ratio 차이:", diff)
    print("95% 신뢰구간:", ci)
    print("t-통계량", d)
    print("p-value:", pval)
    print("-"*50)
# Out:
# Results for risk_parity:
# Sharpe ratio (벤치마크, 내): [0.14651619 0.14552373]
# Sharpe ratio 차이: -0.0009924582349623845
# 95% 신뢰구간: (np.float64(-0.12661999489098885), np.float64(0.12463507842106408))
# t-통계량 0.017275032361018683
# p-value: 0.983016983016983
# --------------------------------------------------
# Results for min_var:
# Sharpe ratio (벤치마크, 내): [0.26927347 0.14552373]
# Sharpe ratio 차이: -0.12374973663104466
# 95% 신뢰구간: (np.float64(-0.2643461198554976), np.float64(0.016846646593408315))
# t-통계량 1.7799480064845166
# p-value: 0.08691308691308691
# --------------------------------------------------
# Results for max_sharpe:
# Sharpe ratio (벤치마크, 내): [0.15276274 0.14552373]
# Sharpe ratio 차이: -0.007239005622971584
# 95% 신뢰구간: (np.float64(-0.27595437026032055), np.float64(0.2614763590143774))
# t-통계량 0.05649417969426593
# p-value: 0.961038961038961
# --------------------------------------------------
# Results for paa:
# Sharpe ratio (벤치마크, 내): [0.06451323 0.14552373]
# Sharpe ratio 차이: 0.08101049946158254
# 95% 신뢰구간: (np.float64(-0.1495093870062835), np.float64(0.3115303859294486))
# t-통계량 0.6761051949959838
# p-value: 0.47352647352647353
# --------------------------------------------------
# Results for equal_strategy:
# Sharpe ratio (벤치마크, 내): [0.16905681 0.14552373]
# Sharpe ratio 차이: -0.02353307491472073
# 95% 신뢰구간: (np.float64(-0.19289918290743385), np.float64(0.1458330330779924))
# t-통계량 0.27115109501097545
# p-value: 0.7832167832167832
# --------------------------------------------------

# %%
b_vec=[1, 2, 3, 4, 5, 6]

# %%
# best_block_scores = rs.block_size_calibrate(
#     returns=returns,
#     b_vec=[1, 2, 3, 4, 5, 6],  # T=76이므로 6 이상은 피하는게 좋음
#     alpha=0.05,
#     K=300,
#     M=99,
#     T_start=20
# )

# %%
SRs, diff, ci, pval, se, d = rs.bootstrap_inference(
    returns=returns,
    block_size=4,     # 논문 추천값 (T=120 기준)
    alpha=0.05,
    M=1000
)

print("Sharpe ratio (벤치마크, 내):", SRs)
print("Sharpe ratio 차이:", diff)
print("95% 신뢰구간:", ci)
print("t-통계량", d)
print("p-value:", pval)
# Out:
# Sharpe ratio (벤치마크, 내): [0.04638002 0.14552373]
# Sharpe ratio 차이: 0.09914370813964854
# 95% 신뢰구간: (np.float64(-0.16024035789762384), np.float64(0.35852777417692094))
# t-통계량 0.8189565246129267
# p-value: 0.4035964035964036

# %%
diff / se
# Out:
# np.float64(-1.5650429769955672)

# %%
eqaul["equal_asset_weight"]
# Out:
# 2019-01-30    0.054332
# 2019-02-28    0.016301
# 2019-03-28   -0.004392
# 2019-04-26    0.024158
# 2019-05-24   -0.027220
#                 ...
# 2024-09-20    0.034407
# 2024-10-18    0.002778
# 2024-11-15   -0.020486
# 2024-12-16    0.036143
# 2024-12-31   -0.022752
# Name: equal_asset_weight, Length: 76, dtype: float64
