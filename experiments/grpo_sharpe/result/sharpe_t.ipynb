# %%
import pandas as pd
import numpy as np
import robustsharpe as rs

# %%
grpo_best_path = "../result/grpo/grpo_return_33.csv"
grpo_worst_path = "../result/grpo/grpo_return_42.csv"
ppo_best_path = "../result/ppo/ppo_return_25.csv"
ppo_worst_path = "../result/ppo/ppo_return_50.csv"
sac_best_path = "../result/sac/sac_return_50.csv"
sac_worst_path = "../result/sac/sac_return_39.csv"
equal_strategy_path = "../result/equal_strategy.csv"

# %%
grpo_best = pd.read_csv(sac_worst_path, index_col=0)

# %%
eqaul = pd.read_csv(equal_strategy_path, index_col=0)

# %%
my_strategy_returns = np.array(grpo_best["Model"])

# %%
benchmark_returns = np.array(eqaul["equal_asset_weight"])

# %%
returns = np.stack([my_strategy_returns, benchmark_returns], axis=1)  # shape: (T, 2)

# %%
# returns = np.stack([benchmark_returns, my_strategy_returns], axis=1)  # shape: (T, 2)

# %%
# best_block_scores = rs.block_size_calibrate(
#     returns=returns,         # shape (T, 2)
#     b_vec=[1, 2, 4, 6],  # 후보 block size
#     alpha=0.05,
#     M=199,                    # bootstrap per test
#     K=1000,                    # pseudo-sequence 생성 횟수
#     T_start= 20
# )

# %%
b_vec=[1, 2, 3, 4, 5, 6]

# %%
# best_block_scores = rs.block_size_calibrate(
#     returns=returns,
#     b_vec=[1, 2, 3, 4, 5, 6],  # T=76이므로 6 이상은 피하는게 좋음
#     alpha=0.05,
#     K=300,
#     M=99,
#     T_start=20
# )

# %%
SRs, diff, ci, pval, se, d = rs.bootstrap_inference(
    returns=returns,
    block_size=4,     # 논문 추천값 (T=120 기준)
    alpha=0.05,
    M=1000
)

print("Sharpe ratio (벤치마크, 내):", SRs)
print("Sharpe ratio 차이:", diff)
print("95% 신뢰구간:", ci)
print("t-통계량", d)
print("p-value:", pval)
# Out:
# Sharpe ratio (벤치마크, 내): [0.04638002 0.14552373]
# Sharpe ratio 차이: 0.09914370813964854
# 95% 신뢰구간: (np.float64(-0.16024035789762384), np.float64(0.35852777417692094))
# t-통계량 0.8189565246129267
# p-value: 0.4035964035964036

# %%
diff / se
# Out:
# np.float64(-1.5650429769955672)

# %%
eqaul["equal_asset_weight"]
# Out:
# 2019-01-30    0.054332
# 2019-02-28    0.016301
# 2019-03-28   -0.004392
# 2019-04-26    0.024158
# 2019-05-24   -0.027220
#                 ...
# 2024-09-20    0.034407
# 2024-10-18    0.002778
# 2024-11-15   -0.020486
# 2024-12-16    0.036143
# 2024-12-31   -0.022752
# Name: equal_asset_weight, Length: 76, dtype: float64
