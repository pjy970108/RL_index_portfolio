# %%
import pandas as pd
import numpy as np

# %%
test_return = pd.read_csv("0.003_benchmark.csv", header=0, index_col=0)

# %%
test_return
# Out:
#             risk_parity   min_var  max_sharpe       paa  equal_strategy  \
# 2019-01-30     0.060012  0.041212   -0.079102 -0.016721        0.001350
# 2019-02-28     0.020955  0.012108    0.026901  0.012351        0.018079
# 2019-03-28    -0.005156 -0.010123   -0.008995 -0.011004       -0.008819
# 2019-04-26     0.027753  0.005332    0.021694  0.021245        0.019006
# 2019-05-24    -0.027919 -0.013556   -0.030867 -0.034561       -0.026726
# ...                 ...       ...         ...       ...             ...
# 2024-09-20     0.030146  0.041552    0.007695 -0.025107        0.013572
# 2024-10-18     0.007070  0.013938    0.026079  0.014277        0.015341
# 2024-11-15    -0.043323 -0.028632   -0.006021  0.006907       -0.017767
# 2024-12-16     0.018710  0.022765    0.065300  0.083412        0.047547
# 2024-12-31    -0.031201 -0.023565   -0.021229  0.005053       -0.017736
#
#             equal_asset_weight
# 2019-01-30            0.054127
# 2019-02-28            0.019223
# 2019-03-28           -0.003245
# 2019-04-26            0.027546
# 2019-05-24           -0.031184
# ...                        ...
# 2024-09-20            0.034196
# 2024-10-18            0.001142
# 2024-11-15           -0.016485
# 2024-12-16            0.037941
# 2024-12-31           -0.022863
#
# [76 rows x 6 columns]

# %%
# grpo_best = grpo_best[["equal_asset_weight"]]
# grpo_best.rename(columns={"equal_asset_weight": "Model"}, inplace=True)

# %%
test_return[test_return["equal_asset_weight"] >=0]["equal_asset_weight"].describe()
# Out:
# count    48.000000
# mean      0.031096
# std       0.026800
# min       0.001071
# 25%       0.012493
# 50%       0.027305
# 75%       0.038073
# max       0.126259
# Name: equal_asset_weight, dtype: float64

# %%
test_return[test_return["equal_asset_weight"] <0]["equal_asset_weight"].describe()
# Out:
# count    28.000000
# mean     -0.036148
# std       0.038877
# min      -0.146382
# 25%      -0.043559
# 50%      -0.023317
# 75%      -0.008128
# max      -0.000691
# Name: equal_asset_weight, dtype: float64

# %%
for col in test_return.columns:
    model = test_return[col]
    gross_profit = model[model >= 0].sum()
    gross_loss = model[model < 0].sum()
    profit_factor = gross_profit / abs(gross_loss) if gross_loss != 0 else np.nan
    print(f"gross_profit for {col}: {gross_profit:.4f}")
    print(f"gross_loss for {col}: {gross_loss:.4f}")
    print(f"Profit Factor for {col}: {profit_factor:.4f}")
    print("profitabel_months:", (test_return[col] > 0).sum())
    print("unprofitabel_months:", (test_return[col] < 0).sum())
    print("-"*50)
# Out:
# gross_profit for risk_parity: 1.4311
# gross_loss for risk_parity: -0.9511
# Profit Factor for risk_parity: 1.5047
# profitabel_months: 47
# unprofitabel_months: 29
# --------------------------------------------------
# gross_profit for min_var: 1.4077
# gross_loss for min_var: -0.6265
# Profit Factor for min_var: 2.2469
# profitabel_months: 50
# unprofitabel_months: 26
# --------------------------------------------------
# gross_profit for max_sharpe: 1.9315
# gross_loss for max_sharpe: -1.3838
# Profit Factor for max_sharpe: 1.3958
# profitabel_months: 44
# unprofitabel_months: 32
# --------------------------------------------------
# gross_profit for paa: 1.7666
# gross_loss for paa: -1.0768
# Profit Factor for paa: 1.6405
# profitabel_months: 51
# unprofitabel_months: 25
# --------------------------------------------------
# gross_profit for equal_strategy: 1.4316
# gross_loss for equal_strategy: -0.8070
# Profit Factor for equal_strategy: 1.7741
# profitabel_months: 51
# unprofitabel_months: 25
# --------------------------------------------------
# gross_profit for equal_asset_weight: 1.4926
# gross_loss for equal_asset_weight: -1.0121
# Profit Factor for equal_asset_weight: 1.4747
# profitabel_months: 48
# unprofitabel_months: 28
# --------------------------------------------------

# %%
model
# Out:
# 2019-01-30    0.054127
# 2019-02-28    0.019223
# 2019-03-28   -0.003245
# 2019-04-26    0.027546
# 2019-05-24   -0.031184
#                 ...
# 2024-09-20    0.034196
# 2024-10-18    0.001142
# 2024-11-15   -0.016485
# 2024-12-16    0.037941
# 2024-12-31   -0.022863
# Name: equal_asset_weight, Length: 76, dtype: float64

# %%
model.index.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.index.year
#
# AttributeError: 'Index' object has no attribute 'year'

# %%
for col in test_return.columns:
    model = test_return[col]
    model.index = pd.to_datetime(model.index)
    
    # Series → DataFrame 변환
    model_df = model.to_frame(name='return')
    model_df['year'] = model_df.index.year

    yearly_return = model_df.groupby('year')['return'].sum()
    
    profitable_years = (yearly_return >= 0).sum()
    unprofitable_years = (yearly_return < 0).sum()
    
    print(f"Profitable years for {col}: {profitable_years}, Unprofitable years: {unprofitable_years}")
# Out:
# Profitable years for risk_parity: 5, Unprofitable years: 1
# Profitable years for min_var: 5, Unprofitable years: 1
# Profitable years for max_sharpe: 4, Unprofitable years: 2
# Profitable years for paa: 4, Unprofitable years: 2
# Profitable years for equal_strategy: 5, Unprofitable years: 1
# Profitable years for equal_asset_weight: 4, Unprofitable years: 2

# %%
    # 1. 인덱스를 datetime 형식으로 변환
grpo_best.index = pd.to_datetime(grpo_best.index)
grpo_best['year'] = grpo_best.index.year
yearly_return = grpo_best.groupby('year')['Model'].sum()
# 4. 수익이 난 해 / 손실이 난 해 개수
profitable_years = (yearly_return > 0).sum()
unprofitable_years = (yearly_return <= 0).sum()

print(f"Profitable years: {profitable_years}, Unprofitable years: {unprofitable_years}")

# %%
gross_profit
# Out:
# Model    1.568973
# dtype: float64

# %%
gross_loss = abs(grpo_best[grpo_best["Model"] < 0].sum())

# %%
grpo_best[grpo_best["Model"] < 0].describe()
# Out:
#            Model
# count  32.000000
# mean   -0.019697
# std     0.020360
# min    -0.087862
# 25%    -0.023889
# 50%    -0.016266
# 75%    -0.005670
# max    -0.000666

# %%
(grpo_best<0).sum()
# Out:
# Model    32
# dtype: int64

# %%
gross_loss
# Out:
# Model    0.630309
# dtype: float64

# %%
profit_factor = gross_profit.values / gross_loss.values if gross_loss.values != 0 else np.inf

# %%
profit_factor
# Out:
# array([2.48921445])

# %%
print("profitable_month" , (grpo_best>=0).sum()
        , "unprofitable_month" , (grpo_best<0).sum())
# Out:
# profitable_month Model    44
# dtype: int64 unprofitable_month Model    32
# dtype: int64

# %%
# 1. 인덱스를 datetime 형식으로 변환
grpo_best.index = pd.to_datetime(grpo_best.index)
grpo_best['year'] = grpo_best.index.year
yearly_return = grpo_best.groupby('year')['Model'].sum()
# 4. 수익이 난 해 / 손실이 난 해 개수
profitable_years = (yearly_return > 0).sum()
unprofitable_years = (yearly_return <= 0).sum()

print(f"Profitable years: {profitable_years}, Unprofitable years: {unprofitable_years}")

# %%
# 3. 연도별 수익률 합계

# %%
# Out:
# Profitable years: 5, Unprofitable years: 1
