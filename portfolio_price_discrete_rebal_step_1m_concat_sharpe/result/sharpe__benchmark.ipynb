# %%
import pandas as pd
import numpy as np
import robustsharpe as rs

# %%
test_return = pd.read_csv("./benchmark/0.003_benchmark.csv", header=0, index_col=0)

# %%
test_return.columns
# Out:
# Index(['risk_parity', 'min_var', 'max_sharpe', 'paa', 'equal_strategy',
#        'equal_asset_weight'],
#       dtype='object')

# %%
benchmark_returns = np.array(test_return["equal_asset_weight"])

col_list = ['risk_parity', 'min_var', 'max_sharpe', 'paa', 'equal_strategy']
for col in col_list:
    my_strategy_returns = np.array(test_return[col])
    
    returns = np.stack([my_strategy_returns, benchmark_returns], axis=1)  # shape: (T, 2)
    SRs, diff, ci, pval, se, d = rs.bootstrap_inference(
        returns=returns,
        block_size=4,     # 논문 추천값 (T=120 기준)
        alpha=0.05,
        M=1000
    )
    print(f"Results for {col}:")
    print("Sharpe ratio (벤치마크, 내):", SRs)
    print("Sharpe ratio 차이:", diff)
    print("95% 신뢰구간:", ci)
    print("t-통계량", d)
    print("p-value:", pval)
    print("-"*50)
# Out:
# Results for risk_parity:
# Sharpe ratio (벤치마크, 내): [0.1465162  0.14552373]
# Sharpe ratio 차이: -0.0009924660246195816
# 95% 신뢰구간: (np.float64(-0.12802264023712934), np.float64(0.12603770818789017))
# t-통계량 0.01727516669950958
# p-value: 0.985014985014985
# --------------------------------------------------
# Results for min_var:
# Sharpe ratio (벤치마크, 내): [0.26927347 0.14552373]
# Sharpe ratio 차이: -0.1237497362408719
# 95% 신뢰구간: (np.float64(-0.2854188911871861), np.float64(0.03791941870544227))
# t-통계량 1.7799480007078894
# p-value: 0.11788211788211789
# --------------------------------------------------
# Results for max_sharpe:
# Sharpe ratio (벤치마크, 내): [0.15276274 0.14552373]
# Sharpe ratio 차이: -0.0072390047600301155
# 95% 신뢰구간: (np.float64(-0.2800620566604666), np.float64(0.2655840471404063))
# t-통계량 0.056494173008157546
# p-value: 0.954045954045954
# --------------------------------------------------
# Results for paa:
# Sharpe ratio (벤치마크, 내): [0.06451323 0.14552373]
# Sharpe ratio 차이: 0.08101050015994685
# 95% 신뢰구간: (np.float64(-0.19658901764983386), np.float64(0.3586100179697276))
# t-통계량 0.6761051996957747
# p-value: 0.5624375624375625
# --------------------------------------------------
# Results for equal_strategy:
# Sharpe ratio (벤치마크, 내): [0.16905681 0.14552373]
# Sharpe ratio 차이: -0.02353307365757304
# 95% 신뢰구간: (np.float64(-0.21305509686682933), np.float64(0.16598894955168325))
# t-통계량 0.2711510803954222
# p-value: 0.7922077922077922
# --------------------------------------------------

# %%
b_vec=[1, 2, 3, 4, 5, 6]

# %%
# best_block_scores = rs.block_size_calibrate(
#     returns=returns,
#     b_vec=[1, 2, 3, 4, 5, 6],  # T=76이므로 6 이상은 피하는게 좋음
#     alpha=0.05,
#     K=300,
#     M=99,
#     T_start=20
# )

# %%
SRs, diff, ci, pval, se, d = rs.bootstrap_inference(
    returns=returns,
    block_size=4,     # 논문 추천값 (T=120 기준)
    alpha=0.05,
    M=1000
)

print("Sharpe ratio (벤치마크, 내):", SRs)
print("Sharpe ratio 차이:", diff)
print("95% 신뢰구간:", ci)
print("t-통계량", d)
print("p-value:", pval)
# Out:
# Sharpe ratio (벤치마크, 내): [0.16905681 0.14552373]
# Sharpe ratio 차이: -0.02353307365757304
# 95% 신뢰구간: (np.float64(-0.1959769389397454), np.float64(0.14891079162459933))
# t-통계량 0.2711510803954222
# p-value: 0.7872127872127872

# %%
diff / se
# Out:
# np.float64(-0.27049446846696307)

# %%
eqaul["equal_asset_weight"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 eqaul["equal_asset_weight"]
#
# NameError: name 'eqaul' is not defined
